# %%
import numpy as np
import matplotlib.pyplot as plt

index = np.arange(5)
values = np.array([5, 7, 3, 4, 6]) * 1000
figure = plt.figure(figsize=(8, 5))
axes = figure.add_subplot(1,1,1)
axes.bar(index,values)
axes.set_xticks(index,['apple', 'banana', 'orange', 'totato', 'guava'])
axes.grid(axis='y')
xmin,xmax,ymin,ymax= axes.axis()
axes.axis([xmin-1, xmax+1, ymin, ymax+1000])

for i in index:
    print(i,values[i],end=' ')
    axes.annotate(str(values[i]),[i-0.2,values[i]+100])
    
    
plt.show()
# Out:
# 0 5000 1 7000 2 3000 3 4000 4 6000

# %%
#ndarray
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
import pandas as pd
series_list = pd.Series(data=[1,2,3,4,5]) #list + 陣列運算
series_list[0], series_list[1], series_list[4]
# Out:
# (1, 2, 5)

# %%
series_dict = pd.Series(data=[1,2,3,4,5],index=['a', 'b', 'c', 'd', 'e']) #dict+ list + 陣列運算
print(series_dict[0], series_dict[1], series_dict[4])
series_dict * 5
# Out:
# 1 2 5
# /tmp/ipykernel_11533/3313479358.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(series_dict[0], series_dict[1], series_dict[4])
# a     5
# b    10
# c    15
# d    20
# e    25
# dtype: int64

# %%
series_dict = pd.Series(data=[89,76,65,92,76],index=['國文', '英文', '數學', '地理', '歷史']) #dict+ list + 陣列運算
series_dict
#series_dict['國文']
# Out:
# 國文    89
# 英文    76
# 數學    65
# 地理    92
# 歷史    76
# dtype: int64

# %%
#Series,values,index
series_dict.values
series_dict.index

series_dict += 3 #陣列運算
series_dict
# Out:
# a     97
# b     98
# c     99
# d    100
# e    101
# dtype: int64

# %%
import matplotlib.pyplot as plt
sdata = pd.Series({'Taipei':35000, 'Taoyuan':71000, 'Taichung':16000, 'Kaohsiung':5000})
figure = plt.figure()
axes = figure.add_subplot()
axes.bar(sdata.index, sdata.values)
plt.show()

# %%
sdata
# Out:
# Taipei       35000
# Taoyuan      71000
# Taichung     16000
# Kaohsiung     5000
# dtype: int64
